# %% [markdown]
# # Discovering the data
#
# Just a few commands to have a look at the data we have. Unrelevant in terms of results, but may contain some useful code lines.

# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
ds = xr.open_mfdataset('/home/mabonnet/Desktop/data/netcdf/2022*.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 2745, y: 77, x: 222)
# Coordinates:
#   * y        (y) float64 3.65 3.55 3.45 3.35 3.25 ... -3.65 -3.75 -3.85 -3.95
#   * x        (x) float64 -16.15 -16.05 -15.95 -15.85 ... 5.65 5.75 5.85 5.95
#   * time     (time) datetime64[ns] 2022-01-01 2022-01-01 ... 2022-02-21T18:00:00
# Data variables:
#     min      (time, y, x) float64 dask.array<chunksize=(95, 77, 222), meta=np.ndarray>
#     max      (time, y, x) float64 dask.array<chunksize=(95, 77, 222), meta=np.ndarray>
#     mean     (time, y, x) float64 dask.array<chunksize=(95, 77, 222), meta=np.ndarray>
#     idw      (time, y, x) float64 dask.array<chunksize=(95, 77, 222), meta=np.ndarray>
#     count    (time, y, x) float64 dask.array<chunksize=(95, 77, 222), meta=np.ndarray>
#     stdev    (time, y, x) float64 dask.array<chunksize=(95, 77, 222), meta=np.ndarray>
# Attributes:
#     transform:     [  0.1   0.  -16.2   0.   -0.1   3.7]
#     res:           [0.1 0.1]
#     is_tiled:      0
# ...

# %%
ds['mean'].isel(time=3).plot()

# %%
(ds['mean'].isel(time=100)-ds['mean'].isel(time=3)).plot(vmin=-0.5, vmax=0.5)

# %%
ds['mean'].isel(x=50, y=50).plot()
